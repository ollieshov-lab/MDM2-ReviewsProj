# %% [markdown]
# ## Questions to ask Huw:
# - We should explain to Huw first what we are model is attempting to do and the outputs we expect to get to provide advice to hotels.
# - What format to use for roBERTA analysis data set, How to format Bert topic output data for sentiment analysis models?
# - Which BERT sentiment analysis model is the most useful(Ro,De,Distill etc.)?
# - How can we use dynamic topic modelling with sentiment analysis to show how sentiment for topics change over time?
# - Are we correct in saying zero-shot modelling is semi-supervised so we can provide a list of topics to the model so it can cluster topics based on these topics? And if so how can we integrate this?
