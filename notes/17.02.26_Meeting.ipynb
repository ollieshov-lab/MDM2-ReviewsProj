# %% [markdown]
# **17-02-26 Meeting**
#
# Objectives -
#
# - String together NLP models to make our own sentiment analysis model
#
# - Test on a section dataset and attune the model to understand more complex reviews (i.e. double negatives, oxymorons like perfect idiot, ect.)
#
# - Once we have an accurate model, we can generate a website displaying the hotel's reviews, ammending inaccurate 'star-ratings' to each hotel
#
# - from this point we can just add more features to the website analysing the data. Current ideas include:
#
# => Seperating the reviews into different areas of the hotel, to see which sections (such as food + beverages, room quatity or the facilities) were rated highly and where could use improvements.
#
# => Looking at how ratings change over time, perhaps referencing causes such as changes to the law and current events like COVID
#
# => how the nationality/demographic of the guests affects their prefences, such as specific customs, and suggest changes to these issues (things like not accounting for dietary requirements or specific prayer rooms)
