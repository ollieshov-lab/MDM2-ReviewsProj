# %% [markdown]
# Lab Session - 16/02/2026

# %% [markdown]
# Transformer model - Vectorising text - which can capture the context allowing machine learning. Classification etc.
#
# Bag of words was used before but doesn’t capture context.
#
# Hotel reviews are topic focused so could use a more simple model like a bag of words.
# But if looking for sentiment analysis vectorising text is the best thing to use.
#
# Analysing sentiment provides a more reliable view of reviews.
# Doesn’t have to be hotels if we can find a better dataset.
#
# Hugging face website provides datasets and pretrained models for free. Bert on hugging face gives a transformer model for free which can vectorise the text for us.
#
# Foundation model is used for learning text.
#
# Stop words can be removed using NLTK library
# Vader - Dictionary model - I.e doctor is positive - Certain nouns have annotative sentiment
#
# Bert can vectorise and pair with sentiment. Can train ML models as input vector and target vector.
# The model doesn’t work well with double negatives.
#
# Latest sentiment analysis can find coupled words.
#
# Topic based analysis for clustering text to find patterns. I.e if people talk about bedding a lot
# latent dirichlet allocation in scikit learn, clusters words together that tend to relate to the same topic. Can say this review covers this topic and does sentiment based analysis.
#
# Can compare reviews from different countries with different datasets and provide a conclusion about how the reviews are for each country.
#
# Can compare our model with Chat GPT to see if it has bias when asked to provide sentiment analysis.
#
# Can use dataset, api to connect directly to reviews (booking.com, tripadvisor) or create bot to website scrape.
